# %% [markdown]
# Data Collection Phase

# %% [markdown]
# Now we download the historical Stock Data

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

ticker = "AAPL"
start_date = "2020-01-01"
end_date = "2024-12-31"

data = yf.download(ticker, start=start_date, end=end_date)
data.head()
# Out:
# /tmp/ipython-input-8-2392336592.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.620842  72.681289  71.373218  71.627092  135480400
# 2020-01-03  71.914825  72.676454  71.689965  71.847125  146322800
# 2020-01-06  72.487854  72.526541  70.783256  71.034717  118387200
# 2020-01-07  72.146950  72.753831  71.926922  72.497537  108872000
# 2020-01-08  73.307510  73.609745  71.849533  71.849533  132079200

# %%
data.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-12-23  254.655716  255.034791  252.840088  254.156919  40858800
# 2024-12-24  257.578674  257.588630  254.675658  254.875189  23234700
# 2024-12-26  258.396667  259.474086  257.010028  257.568678  27237100
# 2024-12-27  254.974930  258.077462  252.451019  257.209530  42355300
# 2024-12-30  251.593094  252.889969  250.146586  251.623020  35557500

# %%
# saving to Local or Drive
data.to_csv("AAPL_stock_data.csv")

# %%
import yfinance as yf
import pandas as pd

ticker = "AAPL"
start_date = "2020-01-01"
end_date = "2024-12-31"

data = yf.download(ticker, start=start_date, end=end_date)
data.to_csv("AAPL_stock_data.csv")
from google.colab import files
files.download("AAPL_stock_data.csv")
# Out:
# /tmp/ipython-input-2-277829816.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(data['Close'], label='Close Price')
plt.title('AAPL Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Stock Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The line graph shows how Apple's closing stock price each day  changed over time
#
# (12 inches wide, 6 inches tall)
